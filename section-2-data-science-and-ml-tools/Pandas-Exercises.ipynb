# %%
import pandas as pd

# %%
color = pd.Series(["Blue","Black","Red"])
color
cars = pd.Series(["BMW","Toyota","Jaguar"])
cars
cars_data = pd.DataFrame({"car" : cars, "color" : color})
cars_data
# Out:
#       car  color
# 0     BMW   Blue
# 1  Toyota  Black
# 2  Jaguar    Red

# %%
car_sales = pd.read_csv("Car-Sales.csv")
car_sales
car_sales.to_csv("Car-Sales_export.csv")

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
# Make             10 non-null object
# Colour           10 non-null object
# Odometer (KM)    10 non-null int64
# Doors            10 non-null int64
# Price            10 non-null object
# dtypes: int64(2), object(3)
# memory usage: 320.0+ bytes

# %%
car_sales.shape
# Out:
# (10, 5)

# %%
numb = pd.Series([2,6.7,5.6,9.0,3.4,6.7,9,3])
numb.sum()
# Out:
# 45.4

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales.iloc[3]
# Out:
# Make                     BMW
# Colour                 Black
# Odometer (KM)          11179
# Doors                      5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
car_sales[car_sales['Odometer (KM)']>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales['Make'],car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
import matplotlib as plt

# %%
car_sales['Odometer (KM)'].plot()

# %%
car_sales['Odometer (KM)'].hist()

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]','')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales['Price'] = car_sales['Price'].str.replace([car_sales['Price']][:-2],'')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4    NaN
# 1   Honda    Red          87899      4    NaN
# 2  Toyota   Blue          32549      3    NaN
# 3     BMW  Black          11179      5    NaN
# 4  Nissan  White         213095      4    NaN
# 5  Toyota  Green          99213      4    NaN
# 6   Honda   Blue          45698      4    NaN
# 7   Honda   Blue          54738      4    NaN
# 8  Toyota  White          60000      4    NaN
# 9  Nissan  White          31600      4    NaN

# %%
car_sales = pd.read_csv("Car-Sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'] = car_sales['Price'].str.replace([car_sales['Price']][:-3],"")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4    NaN
# 1   Honda    Red          87899      4    NaN
# 2  Toyota   Blue          32549      3    NaN
# 3     BMW  Black          11179      5    NaN
# 4  Nissan  White         213095      4    NaN
# 5  Toyota  Green          99213      4    NaN
# 6   Honda   Blue          45698      4    NaN
# 7   Honda   Blue          54738      4    NaN
# 8  Toyota  White          60000      4    NaN
# 9  Nissan  White          31600      4    NaN

# %%
car_sales['Price'] = car_sales['Price'].astype(int)

# %%
car_sales['Price'].plot()

# %%
car_sales['Make'] = car_sales['Make'].str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
cars_missing = pd.read_csv("car-sales-missing.csv")
cars_missing
# Out:
#      Make Colour  Odometer  Doors     Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0       NaN
# 8  Toyota  White   60000.0    NaN       NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
cars_missing['Odometer'] = cars_missing['Odometer'].fillna(cars_missing['Odometer'].mean())
cars_missing
# Out:
#      Make Colour       Odometer  Doors     Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0       NaN
# 8  Toyota  White   60000.000000    NaN       NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
cars_missing = cars_missing.dropna()
cars_missing
# Out:
#      Make Colour       Odometer  Doors     Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
cars_missing['seat'] = 5
cars_missing
# Out:
# C:\Users\ruchigupta3\Python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      Make Colour       Odometer  Doors     Price  seat
# 0  Toyota  White  150043.000000    4.0   $4,000      5
# 1   Honda    Red   87899.000000    4.0   $5,000      5
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5
# 3     BMW  Black   11179.000000    5.0  $22,000      5
# 4  Nissan  White  213095.000000    4.0   $3,500      5
# 5  Toyota  Green   92302.666667    4.0   $4,500      5

# %%
engine_size = [1.3,1.4,1.5,1.3,1.4,1.5]
cars_missing['engine_size'] = engine_size
cars_missing
# Out:
# C:\Users\ruchigupta3\Python\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      Make Colour       Odometer  Doors     Price  seat  engine_size
# 0  Toyota  White  150043.000000    4.0   $4,000      5          1.3
# 1   Honda    Red   87899.000000    4.0   $5,000      5          1.4
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5          1.5
# 3     BMW  Black   11179.000000    5.0  $22,000      5          1.3
# 4  Nissan  White  213095.000000    4.0   $3,500      5          1.4
# 5  Toyota  Green   92302.666667    4.0   $4,500      5          1.5

# %%
cars_missing1 = cars_missing
cars_missing1
# Out:
#      Make Colour       Odometer  Doors     Price  seat  engine_size
# 0  Toyota  White  150043.000000    4.0   $4,000      5          1.3
# 1   Honda    Red   87899.000000    4.0   $5,000      5          1.4
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5          1.5
# 3     BMW  Black   11179.000000    5.0  $22,000      5          1.3
# 4  Nissan  White  213095.000000    4.0   $3,500      5          1.4
# 5  Toyota  Green   92302.666667    4.0   $4,500      5          1.5

# %%
cars_missing1['priceperkm'] = (cars_missing1['Odometer']/10000 * cars_missing1['Price'].str.replace('[\$\\.\,]','').astype(int))/10000
cars_missing1
# Out:
# C:\Users\ruchigupta3\Python\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      Make Colour       Odometer  Doors     Price  seat  engine_size  \
# 0  Toyota  White  150043.000000    4.0   $4,000      5          1.3
# 1   Honda    Red   87899.000000    4.0   $5,000      5          1.4
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5          1.5
# 3     BMW  Black   11179.000000    5.0  $22,000      5          1.3
# 4  Nissan  White  213095.000000    4.0   $3,500      5          1.4
# 5  Toyota  Green   92302.666667    4.0   $4,500      5          1.5
#
#    priceperkm
# 0    6.001720
# 1    4.394950
# 2    6.461187
# 3    2.459380
# 4    7.458325
# ...

# %%
cars_missing1 = cars_missing1.drop('priceperkm',axis=1)
cars_missing1
# Out:
#      Make Colour       Odometer  Doors     Price  seat  engine_size
# 0  Toyota  White  150043.000000    4.0   $4,000      5          1.3
# 1   Honda    Red   87899.000000    4.0   $5,000      5          1.4
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5          1.5
# 3     BMW  Black   11179.000000    5.0  $22,000      5          1.3
# 4  Nissan  White  213095.000000    4.0   $3,500      5          1.4
# 5  Toyota  Green   92302.666667    4.0   $4,500      5          1.5

# %%
cars_missing1.sample(frac=1)
# Out:
#      Make Colour       Odometer  Doors     Price  seat  engine_size
# 3     BMW  Black   11179.000000    5.0  $22,000      5          1.3
# 4  Nissan  White  213095.000000    4.0   $3,500      5          1.4
# 1   Honda    Red   87899.000000    4.0   $5,000      5          1.4
# 5  Toyota  Green   92302.666667    4.0   $4,500      5          1.5
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5          1.5
# 0  Toyota  White  150043.000000    4.0   $4,000      5          1.3
